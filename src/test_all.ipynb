# %% [markdown]
# # AI Chess Agent Project

# %%
import time
import chess
from IPython.display import display, HTML, clear_output
import numpy as np
import pandas as pd
import timeit
import random
import chess.engine

# %%
# import our game utilities, agents, and evaluation functions
import ai_chess as ai

# %%
# game rounds per match-up
NUM_ITERATIONS = 1
# result stats per game for pandas dataframee
COLUMNS = ['round_num','iterations', 'depth', 'white agent','black agent','white_victory','winner','moves_played','remain_w_pieces','remaining_b_pieces', 'remaining_tot_pieces']
# turn off svg animation to improve performance
GRAPHICS = None
# stockfish engine executable path
STOCKFISH_PATH = "./stockfish_engine/test/stockfish"

# %% [markdown]
# ### Results Scoreboard

# %%
scoreboard = pd.DataFrame(columns=COLUMNS)

# %% [markdown]
# ## Random Agent vs Random Agent

# %%
game = ai.Game()
white = ai.RandomAgent()
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ## Improved Random Agent vs Random Agent

# %%
game = ai.Game()
white = ai.RandomAgent("improved")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#   round_num iterations depth            white agent   black agent  \
# 1         1          1  None  improved_random_agent  random_agent
# 0         1          1  None           random_agent  random_agent
#
#   white_victory                       winner moves_played remain_w_pieces  \
# 1         False              draw: stalemate          181              14
# 0         False  draw: insufficient material          283               2
#
#   remaining_b_pieces remaining_tot_pieces
# 1                  1                   15
# 0                  1                    3

# %% [markdown]
# ## Naive Agent vs Random Agent

# %%
game = ai.Game()
white = ai.BaseAgent(heuristic="naive")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#   round_num iterations depth            white agent   black agent  \
# 2         1          1  None            naive_agent  random_agent
# 1         1          1  None  improved_random_agent  random_agent
# 0         1          1  None           random_agent  random_agent
#
#   white_victory                       winner moves_played remain_w_pieces  \
# 2         False                  draw: claim           77              13
# 1         False              draw: stalemate          181              14
# 0         False  draw: insufficient material          283               2
#
#   remaining_b_pieces remaining_tot_pieces
# 2                  2                   15
# 1                  1                   15
# 0                  1                    3

# %% [markdown]
# ## Improved Naive Agent vs Random Agent

# %%
game = ai.Game()
white = ai.BaseAgent(heuristic="improved")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#   round_num iterations depth            white agent   black agent  \
# 3         1          1  None         improved_agent  random_agent
# 2         1          1  None            naive_agent  random_agent
# 1         1          1  None  improved_random_agent  random_agent
# 0         1          1  None           random_agent  random_agent
#
#   white_victory                       winner moves_played remain_w_pieces  \
# 3          True       checkmate: White wins!           51              10
# 2         False                  draw: claim           77              13
# 1         False              draw: stalemate          181              14
# 0         False  draw: insufficient material          283               2
#
#   remaining_b_pieces remaining_tot_pieces
# 3                  6                   16
# 2                  2                   15
# 1                  1                   15
# 0                  1                    3

# %% [markdown]
# ## Advanced Naive Agent vs Random Agent

# %%
game = ai.Game()
white = ai.BaseAgent(heuristic="advanced")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#   round_num iterations depth            white agent   black agent  \
# 3         1          1  None         improved_agent  random_agent
# 2         1          1  None            naive_agent  random_agent
# 1         1          1  None  improved_random_agent  random_agent
# 0         1          1  None           random_agent  random_agent
# 4         1          1  None         advanced_agent  random_agent
#
#   white_victory                       winner moves_played remain_w_pieces  \
# 3          True       checkmate: White wins!           51              10
# 2         False                  draw: claim           77              13
# 1         False              draw: stalemate          181              14
# 0         False  draw: insufficient material          283               2
# 4         False                  draw: claim          345               5
#
#   remaining_b_pieces remaining_tot_pieces
# 3                  6                   16
# 2                  2                   15
# 1                  1                   15
# 0                  1                    3
# 4                  6                   11

# %% [markdown]
# ## Naive Mini-Max Agent (Depth 1) vs Random Agent

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=1, heuristic="naive", type="minimax")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#   round_num iterations depth            white agent   black agent  \
# 3         1          1  None         improved_agent  random_agent
# 2         1          1  None            naive_agent  random_agent
# 5         1          1     1    naive_minimax_agent  random_agent
# 1         1          1  None  improved_random_agent  random_agent
# 0         1          1  None           random_agent  random_agent
# 4         1          1  None         advanced_agent  random_agent
#
#   white_victory                       winner moves_played remain_w_pieces  \
# 3          True       checkmate: White wins!           51              10
# 2         False                  draw: claim           77              13
# 5         False                  draw: claim          102              14
# 1         False              draw: stalemate          181              14
# 0         False  draw: insufficient material          283               2
# 4         False                  draw: claim          345               5
#
#   remaining_b_pieces remaining_tot_pieces
# 3                  6                   16
# 2                  2                   15
# 5                  3                   17
# 1                  1                   15
# 0                  1                    3
# 4                  6                   11

# %% [markdown]
# ## Naive Mini-Max Agent (Depth 2) vs Random Agent

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=2, heuristic="naive", type="minimax")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#   round_num iterations depth            white agent   black agent  \
# 6         1          1     2    naive_minimax_agent  random_agent
# 3         1          1  None         improved_agent  random_agent
# 2         1          1  None            naive_agent  random_agent
# 5         1          1     1    naive_minimax_agent  random_agent
# 1         1          1  None  improved_random_agent  random_agent
# 0         1          1  None           random_agent  random_agent
# 4         1          1  None         advanced_agent  random_agent
#
#   white_victory                       winner moves_played remain_w_pieces  \
# 6          True       checkmate: White wins!           29              16
# 3          True       checkmate: White wins!           51              10
# 2         False                  draw: claim           77              13
# 5         False                  draw: claim          102              14
# 1         False              draw: stalemate          181              14
# 0         False  draw: insufficient material          283               2
# 4         False                  draw: claim          345               5
#
#   remaining_b_pieces remaining_tot_pieces
# 6                 12                   28
# 3                  6                   16
# 2                  2                   15
# 5                  3                   17
# 1                  1                   15
# 0                  1                    3
# 4                  6                   11

# %% [markdown]
# ## Naive Mini-Max Agent (Depth 3) vs Random Agent

# %%
# game = ai.Game()
# white = ai.MiniMaxAgent(max_depth=3,heuristic="naive", type="minimax")
# black = ai.RandomAgent()
# 
# results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
# df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
# scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
# scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)

# %% [markdown]
# ## Improved Mini-Max Agent (Depth 1) vs Random Agent

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=1, heuristic="improved", type="minimax")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#   round_num iterations depth             white agent   black agent  \
# 6         1          1     2     naive_minimax_agent  random_agent
# 3         1          1  None          improved_agent  random_agent
# 7         1          1     1  improved_minimax_agent  random_agent
# 2         1          1  None             naive_agent  random_agent
# 5         1          1     1     naive_minimax_agent  random_agent
# 1         1          1  None   improved_random_agent  random_agent
# 0         1          1  None            random_agent  random_agent
# 4         1          1  None          advanced_agent  random_agent
#
#   white_victory                       winner moves_played remain_w_pieces  \
# 6          True       checkmate: White wins!           29              16
# 3          True       checkmate: White wins!           51              10
# 7          True       checkmate: White wins!           75              15
# 2         False                  draw: claim           77              13
# 5         False                  draw: claim          102              14
# 1         False              draw: stalemate          181              14
# 0         False  draw: insufficient material          283               2
# 4         False                  draw: claim          345               5
#
#   remaining_b_pieces remaining_tot_pieces
# 6                 12                   28
# 3                  6                   16
# 7                  3                   18
# 2                  2                   15
# 5                  3                   17
# 1                  1                   15
# 0                  1                    3
# 4                  6                   11

# %% [markdown]
# ## Improved Mini-Max Agent (Depth 2) vs Random Agent

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=2, heuristic="improved", type="minimax")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#   round_num iterations depth             white agent   black agent  \
# 6         1          1     2     naive_minimax_agent  random_agent
# 3         1          1  None          improved_agent  random_agent
# 7         1          1     1  improved_minimax_agent  random_agent
# 8         1          1     2  improved_minimax_agent  random_agent
# 2         1          1  None             naive_agent  random_agent
# 5         1          1     1     naive_minimax_agent  random_agent
# 1         1          1  None   improved_random_agent  random_agent
# 0         1          1  None            random_agent  random_agent
# 4         1          1  None          advanced_agent  random_agent
#
#   white_victory                       winner moves_played remain_w_pieces  \
# 6          True       checkmate: White wins!           29              16
# 3          True       checkmate: White wins!           51              10
# 7          True       checkmate: White wins!           75              15
# 8         False              draw: stalemate           75              15
# 2         False                  draw: claim           77              13
# 5         False                  draw: claim          102              14
# 1         False              draw: stalemate          181              14
# 0         False  draw: insufficient material          283               2
# 4         False                  draw: claim          345               5
#
#   remaining_b_pieces remaining_tot_pieces
# 6                 12                   28
# 3                  6                   16
# 7                  3                   18
# 8                  1                   16
# 2                  2                   15
# 5                  3                   17
# 1                  1                   15
# 0                  1                    3
# 4                  6                   11

# %% [markdown]
# ## Improved Mini-Max Agent (Depth 3) vs Random Agent

# %%
# game = ai.Game()
# white = ai.MiniMaxAgent(max_depth=3, heuristic="improved", type ="minimax")
# black = ai.RandomAgent()
# 
# results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
# df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
# scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
# scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)

# %% [markdown]
# ## Advanced Mini-Max Agent (Depth 1) vs Random Agent

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=1, heuristic="advanced", type="minimax")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#   round_num iterations depth             white agent   black agent  \
# 9         1          1     1  advanced_minimax_agent  random_agent
# 6         1          1     2     naive_minimax_agent  random_agent
# 3         1          1  None          improved_agent  random_agent
# 7         1          1     1  improved_minimax_agent  random_agent
# 8         1          1     2  improved_minimax_agent  random_agent
# 2         1          1  None             naive_agent  random_agent
# 5         1          1     1     naive_minimax_agent  random_agent
# 1         1          1  None   improved_random_agent  random_agent
# 0         1          1  None            random_agent  random_agent
# 4         1          1  None          advanced_agent  random_agent
#
#   white_victory                       winner moves_played remain_w_pieces  \
# 9          True       checkmate: White wins!           25              15
# 6          True       checkmate: White wins!           29              16
# 3          True       checkmate: White wins!           51              10
# 7          True       checkmate: White wins!           75              15
# 8         False              draw: stalemate           75              15
# 2         False                  draw: claim           77              13
# 5         False                  draw: claim          102              14
# 1         False              draw: stalemate          181              14
# 0         False  draw: insufficient material          283               2
# 4         False                  draw: claim          345               5
#
#   remaining_b_pieces remaining_tot_pieces
# 9                 11                   26
# 6                 12                   28
# 3                  6                   16
# 7                  3                   18
# 8                  1                   16
# 2                  2                   15
# 5                  3                   17
# 1                  1                   15
# 0                  1                    3
# 4                  6                   11

# %% [markdown]
# ## Advanced Mini-Max Agent (Depth 2) vs Random Agent

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=2, heuristic="advanced", type="minimax")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth             white agent   black agent  \
# 9          1          1     1  advanced_minimax_agent  random_agent
# 6          1          1     2     naive_minimax_agent  random_agent
# 3          1          1  None          improved_agent  random_agent
# 10         1          1     2  advanced_minimax_agent  random_agent
# 7          1          1     1  improved_minimax_agent  random_agent
# 8          1          1     2  improved_minimax_agent  random_agent
# 2          1          1  None             naive_agent  random_agent
# 5          1          1     1     naive_minimax_agent  random_agent
# 1          1          1  None   improved_random_agent  random_agent
# 0          1          1  None            random_agent  random_agent
# 4          1          1  None          advanced_agent  random_agent
#
#    white_victory                       winner moves_played remain_w_pieces  \
# 9           True       checkmate: White wins!           25              15
# 6           True       checkmate: White wins!           29              16
# 3           True       checkmate: White wins!           51              10
# 10          True       checkmate: White wins!           61              15
# 7           True       checkmate: White wins!           75              15
# 8          False              draw: stalemate           75              15
# 2          False                  draw: claim           77              13
# 5          False                  draw: claim          102              14
# 1          False              draw: stalemate          181              14
# 0          False  draw: insufficient material          283               2
# 4          False                  draw: claim          345               5
#
#    remaining_b_pieces remaining_tot_pieces
# 9                  11                   26
# 6                  12                   28
# 3                   6                   16
# 10                  2                   17
# 7                   3                   18
# 8                   1                   16
# 2                   2                   15
# 5                   3                   17
# 1                   1                   15
# 0                   1                    3
# 4                   6                   11

# %% [markdown]
# ## Advanced Mini-Max Agent (Depth 3) vs Random Agent

# %%
# game = ai.Game()
# white = ai.MiniMaxAgent(max_depth=3, heuristic="advanced", type="minimax")
# black = ai.RandomAgent()
# 
# results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
# df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
# scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
# scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)

# %% [markdown]
# ## Naive Mini-Max with Alpha-Beta-Pruning Agent (Depth 1) vs Random Agent

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=1, heuristic="naive", type="alpha-beta")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                     white agent   black agent  \
# 9          1          1     1          advanced_minimax_agent  random_agent
# 6          1          1     2             naive_minimax_agent  random_agent
# 3          1          1  None                  improved_agent  random_agent
# 10         1          1     2          advanced_minimax_agent  random_agent
# 7          1          1     1          improved_minimax_agent  random_agent
# 8          1          1     2          improved_minimax_agent  random_agent
# 2          1          1  None                     naive_agent  random_agent
# 11         1          1     1  naive_alpha-beta_minimax_agent  random_agent
# 5          1          1     1             naive_minimax_agent  random_agent
# 1          1          1  None           improved_random_agent  random_agent
# 0          1          1  None                    random_agent  random_agent
# 4          1          1  None                  advanced_agent  random_agent
#
#    white_victory                       winner moves_played remain_w_pieces  \
# 9           True       checkmate: White wins!           25              15
# 6           True       checkmate: White wins!           29              16
# 3           True       checkmate: White wins!           51              10
# 10          True       checkmate: White wins!           61              15
# 7           True       checkmate: White wins!           75              15
# 8          False              draw: stalemate           75              15
# 2          False                  draw: claim           77              13
# 11         False                  draw: claim           85              16
# 5          False                  draw: claim          102              14
# 1          False              draw: stalemate          181              14
# 0          False  draw: insufficient material          283               2
# 4          False                  draw: claim          345               5
#
#    remaining_b_pieces remaining_tot_pieces
# 9                  11                   26
# 6                  12                   28
# 3                   6                   16
# 10                  2                   17
# 7                   3                   18
# 8                   1                   16
# 2                   2                   15
# 11                  5                   21
# 5                   3                   17
# 1                   1                   15
# 0                   1                    3
# 4                   6                   11

# %% [markdown]
# ## Naive Mini-Max with Alpha-Beta-Pruning Agent (Depth 2) vs Random Agent

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=2, heuristic="naive", type="alpha-beta")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                     white agent   black agent  \
# 9          1          1     1          advanced_minimax_agent  random_agent
# 6          1          1     2             naive_minimax_agent  random_agent
# 3          1          1  None                  improved_agent  random_agent
# 12         1          1     2  naive_alpha-beta_minimax_agent  random_agent
# 10         1          1     2          advanced_minimax_agent  random_agent
# 7          1          1     1          improved_minimax_agent  random_agent
# 8          1          1     2          improved_minimax_agent  random_agent
# 2          1          1  None                     naive_agent  random_agent
# 11         1          1     1  naive_alpha-beta_minimax_agent  random_agent
# 5          1          1     1             naive_minimax_agent  random_agent
# 1          1          1  None           improved_random_agent  random_agent
# 0          1          1  None                    random_agent  random_agent
# 4          1          1  None                  advanced_agent  random_agent
#
#    white_victory                       winner moves_played remain_w_pieces  \
# 9           True       checkmate: White wins!           25              15
# 6           True       checkmate: White wins!           29              16
# 3           True       checkmate: White wins!           51              10
# 12         False                  draw: claim           51              15
# 10          True       checkmate: White wins!           61              15
# 7           True       checkmate: White wins!           75              15
# 8          False              draw: stalemate           75              15
# 2          False                  draw: claim           77              13
# 11         False                  draw: claim           85              16
# 5          False                  draw: claim          102              14
# 1          False              draw: stalemate          181              14
# 0          False  draw: insufficient material          283               2
# 4          False                  draw: claim          345               5
#
#    remaining_b_pieces remaining_tot_pieces
# 9                  11                   26
# 6                  12                   28
# 3                   6                   16
# 12                  2                   17
# 10                  2                   17
# 7                   3                   18
# 8                   1                   16
# 2                   2                   15
# 11                  5                   21
# 5                   3                   17
# 1                   1                   15
# 0                   1                    3
# 4                   6                   11

# %% [markdown]
# ## Naive Mini-Max with Alpha-Beta-Pruning Agent (Depth 3) vs Random Agent

# %%
# game = ai.Game()
# white = ai.MiniMaxAgent(max_depth=3, heuristic="naive", type="alpha-beta")
# black = ai.RandomAgent()
# 
# results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
# df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
# scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
# scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)

# %% [markdown]
# ## Improved Mini-Max with Alpha-Beta-Pruning Agent (Depth 1) vs Random Agent

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=1, heuristic="improved", type="alpha-beta")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 9          1          1     1             advanced_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 3          1          1  None                     improved_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 9   random_agent          True       checkmate: White wins!           25
# 6   random_agent          True       checkmate: White wins!           29
# 3   random_agent          True       checkmate: White wins!           51
# 12  random_agent         False                  draw: claim           51
# 13  random_agent         False              draw: stalemate           53
# 10  random_agent          True       checkmate: White wins!           61
# 7   random_agent          True       checkmate: White wins!           75
# 8   random_agent         False              draw: stalemate           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 9               15                 11                   26
# 6               16                 12                   28
# 3               10                  6                   16
# 12              15                  2                   17
# 13              14                  1                   15
# 10              15                  2                   17
# 7               15                  3                   18
# 8               15                  1                   16
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Improved Mini-Max with Alpha-Beta-Pruning Agent (Depth 2) vs Random Agent

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=2, heuristic="improved", type="alpha-beta")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 3          1          1  None                     improved_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 6   random_agent          True       checkmate: White wins!           29
# 3   random_agent          True       checkmate: White wins!           51
# 12  random_agent         False                  draw: claim           51
# 13  random_agent         False              draw: stalemate           53
# 10  random_agent          True       checkmate: White wins!           61
# 7   random_agent          True       checkmate: White wins!           75
# 8   random_agent         False              draw: stalemate           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 9               15                 11                   26
# 14              16                  5                   21
# 6               16                 12                   28
# 3               10                  6                   16
# 12              15                  2                   17
# 13              14                  1                   15
# 10              15                  2                   17
# 7               15                  3                   18
# 8               15                  1                   16
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Improved Mini-Max with Alpha-Beta-Pruning Agent (Depth 3) vs Random Agent

# %%
# game = ai.Game()
# white = ai.MiniMaxAgent(max_depth=3, heuristic="improved", type="alpha-beta")
# black = ai.RandomAgent()
# 
# results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
# df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
# scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
# scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)

# %% [markdown]
# ## Advanced Mini-Max with Alpha-Beta-Pruning Agent (Depth 1) vs Random Agent

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=1, heuristic="advanced", type="alpha-beta")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 6   random_agent          True       checkmate: White wins!           29
# 15  random_agent         False              draw: stalemate           39
# 3   random_agent          True       checkmate: White wins!           51
# 12  random_agent         False                  draw: claim           51
# 13  random_agent         False              draw: stalemate           53
# 10  random_agent          True       checkmate: White wins!           61
# 7   random_agent          True       checkmate: White wins!           75
# 8   random_agent         False              draw: stalemate           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 9               15                 11                   26
# 14              16                  5                   21
# 6               16                 12                   28
# 15              15                  2                   17
# 3               10                  6                   16
# 12              15                  2                   17
# 13              14                  1                   15
# 10              15                  2                   17
# 7               15                  3                   18
# 8               15                  1                   16
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Advanced Mini-Max with Alpha-Beta-Pruning Agent (Depth 2) vs Random Agent

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=2, heuristic="advanced", type="alpha-beta")
black = ai.RandomAgent()

results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 6   random_agent          True       checkmate: White wins!           29
# 15  random_agent         False              draw: stalemate           39
# 16  random_agent          True       checkmate: White wins!           47
# 3   random_agent          True       checkmate: White wins!           51
# 12  random_agent         False                  draw: claim           51
# 13  random_agent         False              draw: stalemate           53
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 9               15                 11                   26
# 14              16                  5                   21
# 6               16                 12                   28
# 15              15                  2                   17
# 16              13                  7                   20
# 3               10                  6                   16
# 12              15                  2                   17
# 13              14                  1                   15
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Advanced Mini-Max with Alpha-Beta-Pruning Agent (Depth 3) vs Random Agent

# %%
# game = ai.Game()
# white = ai.MiniMaxAgent(max_depth=3, heuristic="advanced", type="alpha-beta")
# black = ai.RandomAgent()
# 
# results = game.run(white, black, NUM_ITERATIONS, visual=None)

# %%
# df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
# scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
# scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)


## Random Agent vs Stockfish

# %%
game = ai.Game()
white = ai.RandomAgent()
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 6   random_agent          True       checkmate: White wins!           29
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 16  random_agent          True       checkmate: White wins!           47
# 3   random_agent          True       checkmate: White wins!           51
# 12  random_agent         False                  draw: claim           51
# 13  random_agent         False              draw: stalemate           53
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 9               15                 11                   26
# 14              16                  5                   21
# 6               16                 12                   28
# 17               9                 15                   24
# 15              15                  2                   17
# 16              13                  7                   20
# 3               10                  6                   16
# 12              15                  2                   17
# 13              14                  1                   15
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Improved Random Agent vs Stockfish

# %%
game = ai.Game()
white = ai.RandomAgent("improved")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 18         1          1  None              improved_random_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 18     stockfish         False       checkmate: Black wins!           22
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 6   random_agent          True       checkmate: White wins!           29
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 16  random_agent          True       checkmate: White wins!           47
# 3   random_agent          True       checkmate: White wins!           51
# 12  random_agent         False                  draw: claim           51
# 13  random_agent         False              draw: stalemate           53
# 10  random_agent          True       checkmate: White wins!           61
# 7   random_agent          True       checkmate: White wins!           75
# 8   random_agent         False              draw: stalemate           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 18              12                 13                   25
# 9               15                 11                   26
# 14              16                  5                   21
# 6               16                 12                   28
# 17               9                 15                   24
# 15              15                  2                   17
# 16              13                  7                   20
# 3               10                  6                   16
# 12              15                  2                   17
# 13              14                  1                   15
# 10              15                  2                   17
# 7               15                  3                   18
# 8               15                  1                   16
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Naive Agent vs Stockfish

# %%
game = ai.Game()
white = ai.BaseAgent(heuristic="naive")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 19         1          1  None                        naive_agent
# 18         1          1  None              improved_random_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 19     stockfish         False       checkmate: Black wins!           16
# 18     stockfish         False       checkmate: Black wins!           22
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 6   random_agent          True       checkmate: White wins!           29
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 16  random_agent          True       checkmate: White wins!           47
# 3   random_agent          True       checkmate: White wins!           51
# 12  random_agent         False                  draw: claim           51
# 13  random_agent         False              draw: stalemate           53
# 10  random_agent          True       checkmate: White wins!           61
# 7   random_agent          True       checkmate: White wins!           75
# 8   random_agent         False              draw: stalemate           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 19              12                 13                   25
# 18              12                 13                   25
# 9               15                 11                   26
# 14              16                  5                   21
# 6               16                 12                   28
# 17               9                 15                   24
# 15              15                  2                   17
# 16              13                  7                   20
# 3               10                  6                   16
# 12              15                  2                   17
# 13              14                  1                   15
# 10              15                  2                   17
# 7               15                  3                   18
# 8               15                  1                   16
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Improved Naive Agent vs Stockfish

# %%
game = ai.Game()
white = ai.BaseAgent(heuristic="improved")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 19         1          1  None                        naive_agent
# 20         1          1  None                     improved_agent
# 18         1          1  None              improved_random_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 19     stockfish         False       checkmate: Black wins!           16
# 20     stockfish         False       checkmate: Black wins!           22
# 18     stockfish         False       checkmate: Black wins!           22
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 6   random_agent          True       checkmate: White wins!           29
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 16  random_agent          True       checkmate: White wins!           47
# 3   random_agent          True       checkmate: White wins!           51
# 12  random_agent         False                  draw: claim           51
# 13  random_agent         False              draw: stalemate           53
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 19              12                 13                   25
# 20              11                 12                   23
# 18              12                 13                   25
# 9               15                 11                   26
# 14              16                  5                   21
# 6               16                 12                   28
# 17               9                 15                   24
# 15              15                  2                   17
# 16              13                  7                   20
# 3               10                  6                   16
# 12              15                  2                   17
# 13              14                  1                   15
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Advanced Naive Agent vs Stockfish

# %%
game = ai.Game()
white = ai.BaseAgent(heuristic="advanced")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 19         1          1  None                        naive_agent
# 21         1          1  None                     advanced_agent
# 18         1          1  None              improved_random_agent
# 20         1          1  None                     improved_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 19     stockfish         False       checkmate: Black wins!           16
# 21     stockfish         False       checkmate: Black wins!           20
# 18     stockfish         False       checkmate: Black wins!           22
# 20     stockfish         False       checkmate: Black wins!           22
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 6   random_agent          True       checkmate: White wins!           29
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 16  random_agent          True       checkmate: White wins!           47
# 3   random_agent          True       checkmate: White wins!           51
# 12  random_agent         False                  draw: claim           51
# 13  random_agent         False              draw: stalemate           53
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 19              12                 13                   25
# 21              12                 13                   25
# 18              12                 13                   25
# 20              11                 12                   23
# 9               15                 11                   26
# 14              16                  5                   21
# 6               16                 12                   28
# 17               9                 15                   24
# 15              15                  2                   17
# 16              13                  7                   20
# 3               10                  6                   16
# 12              15                  2                   17
# 13              14                  1                   15
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Naive Mini-Max Agent (Depth 1) vs Stockfish

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=1, heuristic="naive", type="minimax")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 19         1          1  None                        naive_agent
# 21         1          1  None                     advanced_agent
# 20         1          1  None                     improved_agent
# 18         1          1  None              improved_random_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 22         1          1     1                naive_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 19     stockfish         False       checkmate: Black wins!           16
# 21     stockfish         False       checkmate: Black wins!           20
# 20     stockfish         False       checkmate: Black wins!           22
# 18     stockfish         False       checkmate: Black wins!           22
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 6   random_agent          True       checkmate: White wins!           29
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 22     stockfish         False       checkmate: Black wins!           46
# 16  random_agent          True       checkmate: White wins!           47
# 12  random_agent         False                  draw: claim           51
# 3   random_agent          True       checkmate: White wins!           51
# 13  random_agent         False              draw: stalemate           53
# 10  random_agent          True       checkmate: White wins!           61
# 7   random_agent          True       checkmate: White wins!           75
# 8   random_agent         False              draw: stalemate           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 19              12                 13                   25
# 21              12                 13                   25
# 20              11                 12                   23
# 18              12                 13                   25
# 9               15                 11                   26
# 14              16                  5                   21
# 6               16                 12                   28
# 17               9                 15                   24
# 15              15                  2                   17
# 22              13                 14                   27
# 16              13                  7                   20
# 12              15                  2                   17
# 3               10                  6                   16
# 13              14                  1                   15
# 10              15                  2                   17
# 7               15                  3                   18
# 8               15                  1                   16
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Naive Mini-Max Agent (Depth 2) vs Stockfish

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=2, heuristic="naive", type="minimax")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 19         1          1  None                        naive_agent
# 21         1          1  None                     advanced_agent
# 18         1          1  None              improved_random_agent
# 20         1          1  None                     improved_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 22         1          1     1                naive_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 23         1          1     2                naive_minimax_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 19     stockfish         False       checkmate: Black wins!           16
# 21     stockfish         False       checkmate: Black wins!           20
# 18     stockfish         False       checkmate: Black wins!           22
# 20     stockfish         False       checkmate: Black wins!           22
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 6   random_agent          True       checkmate: White wins!           29
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 22     stockfish         False       checkmate: Black wins!           46
# 16  random_agent          True       checkmate: White wins!           47
# 23     stockfish         False       checkmate: Black wins!           48
# 12  random_agent         False                  draw: claim           51
# 3   random_agent          True       checkmate: White wins!           51
# 13  random_agent         False              draw: stalemate           53
# 10  random_agent          True       checkmate: White wins!           61
# 7   random_agent          True       checkmate: White wins!           75
# 8   random_agent         False              draw: stalemate           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 19              12                 13                   25
# 21              12                 13                   25
# 18              12                 13                   25
# 20              11                 12                   23
# 9               15                 11                   26
# 14              16                  5                   21
# 6               16                 12                   28
# 17               9                 15                   24
# 15              15                  2                   17
# 22              13                 14                   27
# 16              13                  7                   20
# 23              12                 14                   26
# 12              15                  2                   17
# 3               10                  6                   16
# 13              14                  1                   15
# 10              15                  2                   17
# 7               15                  3                   18
# 8               15                  1                   16
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Naive Mini-Max Agent (Depth 3) vs Stockfish

# %%
# game = ai.Game()
# white = ai.MiniMaxAgent(max_depth=3,heuristic="naive", type="minimax")
# black = STOCKFISH_PATH
# 
# results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
# df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
# scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
# scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)

# %% [markdown]
# ## Improved Mini-Max Agent (Depth 1) vs Stockfish

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=1, heuristic="improved", type="minimax")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 19         1          1  None                        naive_agent
# 21         1          1  None                     advanced_agent
# 20         1          1  None                     improved_agent
# 18         1          1  None              improved_random_agent
# 24         1          1     1             improved_minimax_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 22         1          1     1                naive_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 23         1          1     2                naive_minimax_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 19     stockfish         False       checkmate: Black wins!           16
# 21     stockfish         False       checkmate: Black wins!           20
# 20     stockfish         False       checkmate: Black wins!           22
# 18     stockfish         False       checkmate: Black wins!           22
# 24     stockfish         False       checkmate: Black wins!           24
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 6   random_agent          True       checkmate: White wins!           29
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 22     stockfish         False       checkmate: Black wins!           46
# 16  random_agent          True       checkmate: White wins!           47
# 23     stockfish         False       checkmate: Black wins!           48
# 12  random_agent         False                  draw: claim           51
# 3   random_agent          True       checkmate: White wins!           51
# 13  random_agent         False              draw: stalemate           53
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 19              12                 13                   25
# 21              12                 13                   25
# 20              11                 12                   23
# 18              12                 13                   25
# 24              13                 15                   28
# 9               15                 11                   26
# 14              16                  5                   21
# 6               16                 12                   28
# 17               9                 15                   24
# 15              15                  2                   17
# 22              13                 14                   27
# 16              13                  7                   20
# 23              12                 14                   26
# 12              15                  2                   17
# 3               10                  6                   16
# 13              14                  1                   15
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Improved Mini-Max Agent (Depth 2) vs Stockfish

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=2, heuristic="improved", type="minimax")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 19         1          1  None                        naive_agent
# 21         1          1  None                     advanced_agent
# 20         1          1  None                     improved_agent
# 18         1          1  None              improved_random_agent
# 25         1          1     2             improved_minimax_agent
# 24         1          1     1             improved_minimax_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 22         1          1     1                naive_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 23         1          1     2                naive_minimax_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 19     stockfish         False       checkmate: Black wins!           16
# 21     stockfish         False       checkmate: Black wins!           20
# 20     stockfish         False       checkmate: Black wins!           22
# 18     stockfish         False       checkmate: Black wins!           22
# 25     stockfish         False       checkmate: Black wins!           24
# 24     stockfish         False       checkmate: Black wins!           24
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 6   random_agent          True       checkmate: White wins!           29
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 22     stockfish         False       checkmate: Black wins!           46
# 16  random_agent          True       checkmate: White wins!           47
# 23     stockfish         False       checkmate: Black wins!           48
# 12  random_agent         False                  draw: claim           51
# 3   random_agent          True       checkmate: White wins!           51
# 13  random_agent         False              draw: stalemate           53
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 19              12                 13                   25
# 21              12                 13                   25
# 20              11                 12                   23
# 18              12                 13                   25
# 25              14                 16                   30
# 24              13                 15                   28
# 9               15                 11                   26
# 14              16                  5                   21
# 6               16                 12                   28
# 17               9                 15                   24
# 15              15                  2                   17
# 22              13                 14                   27
# 16              13                  7                   20
# 23              12                 14                   26
# 12              15                  2                   17
# 3               10                  6                   16
# 13              14                  1                   15
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Improved Mini-Max Agent (Depth 3) vs Stockfish

# %%
# game = ai.Game()
# white = ai.MiniMaxAgent(max_depth=3, heuristic="improved", type ="minimax")
# black = STOCKFISH_PATH

# results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
# df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
# scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
# scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)

# %% [markdown]
# ## Advanced Mini-Max (Depth 1) Agent vs Stockfish

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=1, heuristic="advanced", type="minimax")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 19         1          1  None                        naive_agent
# 21         1          1  None                     advanced_agent
# 20         1          1  None                     improved_agent
# 18         1          1  None              improved_random_agent
# 24         1          1     1             improved_minimax_agent
# 25         1          1     2             improved_minimax_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 22         1          1     1                naive_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 23         1          1     2                naive_minimax_agent
# 3          1          1  None                     improved_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 26         1          1     1             advanced_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 19     stockfish         False       checkmate: Black wins!           16
# 21     stockfish         False       checkmate: Black wins!           20
# 20     stockfish         False       checkmate: Black wins!           22
# 18     stockfish         False       checkmate: Black wins!           22
# 24     stockfish         False       checkmate: Black wins!           24
# 25     stockfish         False       checkmate: Black wins!           24
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 6   random_agent          True       checkmate: White wins!           29
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 22     stockfish         False       checkmate: Black wins!           46
# 16  random_agent          True       checkmate: White wins!           47
# 23     stockfish         False       checkmate: Black wins!           48
# 3   random_agent          True       checkmate: White wins!           51
# 12  random_agent         False                  draw: claim           51
# 13  random_agent         False              draw: stalemate           53
# 26     stockfish         False       checkmate: Black wins!           60
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 19              12                 13                   25
# 21              12                 13                   25
# 20              11                 12                   23
# 18              12                 13                   25
# 24              13                 15                   28
# 25              14                 16                   30
# 9               15                 11                   26
# 14              16                  5                   21
# 6               16                 12                   28
# 17               9                 15                   24
# 15              15                  2                   17
# 22              13                 14                   27
# 16              13                  7                   20
# 23              12                 14                   26
# 3               10                  6                   16
# 12              15                  2                   17
# 13              14                  1                   15
# 26               8                 11                   19
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Advanced Mini-Max Agent (Depth 2) vs Stockfish

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=2, heuristic="advanced", type="minimax")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)\

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 19         1          1  None                        naive_agent
# 21         1          1  None                     advanced_agent
# 20         1          1  None                     improved_agent
# 18         1          1  None              improved_random_agent
# 25         1          1     2             improved_minimax_agent
# 24         1          1     1             improved_minimax_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 27         1          1     2             advanced_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 22         1          1     1                naive_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 23         1          1     2                naive_minimax_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 26         1          1     1             advanced_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 19     stockfish         False       checkmate: Black wins!           16
# 21     stockfish         False       checkmate: Black wins!           20
# 20     stockfish         False       checkmate: Black wins!           22
# 18     stockfish         False       checkmate: Black wins!           22
# 25     stockfish         False       checkmate: Black wins!           24
# 24     stockfish         False       checkmate: Black wins!           24
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 27     stockfish         False       checkmate: Black wins!           28
# 6   random_agent          True       checkmate: White wins!           29
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 22     stockfish         False       checkmate: Black wins!           46
# 16  random_agent          True       checkmate: White wins!           47
# 23     stockfish         False       checkmate: Black wins!           48
# 12  random_agent         False                  draw: claim           51
# 3   random_agent          True       checkmate: White wins!           51
# 13  random_agent         False              draw: stalemate           53
# 26     stockfish         False       checkmate: Black wins!           60
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 19              12                 13                   25
# 21              12                 13                   25
# 20              11                 12                   23
# 18              12                 13                   25
# 25              14                 16                   30
# 24              13                 15                   28
# 9               15                 11                   26
# 14              16                  5                   21
# 27              11                 14                   25
# 6               16                 12                   28
# 17               9                 15                   24
# 15              15                  2                   17
# 22              13                 14                   27
# 16              13                  7                   20
# 23              12                 14                   26
# 12              15                  2                   17
# 3               10                  6                   16
# 13              14                  1                   15
# 26               8                 11                   19
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Advanced Mini-Max Agent (Depth 3) vs Stockfish

# %%
# game = ai.Game()
# white = ai.MiniMaxAgent(max_depth=3, heuristic="advanced", type="minimax")
# black = STOCKFISH_PATH
# 
# results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
# df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
# scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
# scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)

# %% [markdown]
# ## Naive Mini-Max with Alpha-Beta-Pruning Agent (Depth 1) vs Stockfish

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=1, heuristic="naive", type="alpha-beta")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 19         1          1  None                        naive_agent
# 21         1          1  None                     advanced_agent
# 20         1          1  None                     improved_agent
# 18         1          1  None              improved_random_agent
# 25         1          1     2             improved_minimax_agent
# 24         1          1     1             improved_minimax_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 27         1          1     2             advanced_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 28         1          1     1     naive_alpha-beta_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 22         1          1     1                naive_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 23         1          1     2                naive_minimax_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 26         1          1     1             advanced_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 19     stockfish         False       checkmate: Black wins!           16
# 21     stockfish         False       checkmate: Black wins!           20
# 20     stockfish         False       checkmate: Black wins!           22
# 18     stockfish         False       checkmate: Black wins!           22
# 25     stockfish         False       checkmate: Black wins!           24
# 24     stockfish         False       checkmate: Black wins!           24
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 27     stockfish         False       checkmate: Black wins!           28
# 6   random_agent          True       checkmate: White wins!           29
# 28     stockfish         False       checkmate: Black wins!           32
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 22     stockfish         False       checkmate: Black wins!           46
# 16  random_agent          True       checkmate: White wins!           47
# 23     stockfish         False       checkmate: Black wins!           48
# 12  random_agent         False                  draw: claim           51
# 3   random_agent          True       checkmate: White wins!           51
# 13  random_agent         False              draw: stalemate           53
# 26     stockfish         False       checkmate: Black wins!           60
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 19              12                 13                   25
# 21              12                 13                   25
# 20              11                 12                   23
# 18              12                 13                   25
# 25              14                 16                   30
# 24              13                 15                   28
# 9               15                 11                   26
# 14              16                  5                   21
# 27              11                 14                   25
# 6               16                 12                   28
# 28              15                 15                   30
# 17               9                 15                   24
# 15              15                  2                   17
# 22              13                 14                   27
# 16              13                  7                   20
# 23              12                 14                   26
# 12              15                  2                   17
# 3               10                  6                   16
# 13              14                  1                   15
# 26               8                 11                   19
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Naive Mini-Max with Alpha-Beta-Pruning Agent (Depth 2) vs Stockfish

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=2, heuristic="naive", type="alpha-beta")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 19         1          1  None                        naive_agent
# 21         1          1  None                     advanced_agent
# 20         1          1  None                     improved_agent
# 18         1          1  None              improved_random_agent
# 29         1          1     2     naive_alpha-beta_minimax_agent
# 25         1          1     2             improved_minimax_agent
# 24         1          1     1             improved_minimax_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 27         1          1     2             advanced_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 28         1          1     1     naive_alpha-beta_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 22         1          1     1                naive_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 23         1          1     2                naive_minimax_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 26         1          1     1             advanced_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 19     stockfish         False       checkmate: Black wins!           16
# 21     stockfish         False       checkmate: Black wins!           20
# 20     stockfish         False       checkmate: Black wins!           22
# 18     stockfish         False       checkmate: Black wins!           22
# 29     stockfish         False       checkmate: Black wins!           24
# 25     stockfish         False       checkmate: Black wins!           24
# 24     stockfish         False       checkmate: Black wins!           24
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 27     stockfish         False       checkmate: Black wins!           28
# 6   random_agent          True       checkmate: White wins!           29
# 28     stockfish         False       checkmate: Black wins!           32
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 22     stockfish         False       checkmate: Black wins!           46
# 16  random_agent          True       checkmate: White wins!           47
# 23     stockfish         False       checkmate: Black wins!           48
# 12  random_agent         False                  draw: claim           51
# 3   random_agent          True       checkmate: White wins!           51
# 13  random_agent         False              draw: stalemate           53
# 26     stockfish         False       checkmate: Black wins!           60
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 19              12                 13                   25
# 21              12                 13                   25
# 20              11                 12                   23
# 18              12                 13                   25
# 29              10                 14                   24
# 25              14                 16                   30
# 24              13                 15                   28
# 9               15                 11                   26
# 14              16                  5                   21
# 27              11                 14                   25
# 6               16                 12                   28
# 28              15                 15                   30
# 17               9                 15                   24
# 15              15                  2                   17
# 22              13                 14                   27
# 16              13                  7                   20
# 23              12                 14                   26
# 12              15                  2                   17
# 3               10                  6                   16
# 13              14                  1                   15
# 26               8                 11                   19
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Naive Mini-Max with Alpha-Beta-Pruning Agent (Depth 3) vs Stockfish

# %%
# game = ai.Game()
# white = ai.MiniMaxAgent(max_depth=3, heuristic="naive", type="alpha-beta")
# black = STOCKFISH_PATH
# 
# results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
# df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
# scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
# scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)

# %% [markdown]
# ## Improved Mini-Max with Alpha-Beta-Pruning Agent (Depth 1) vs Stockfish

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=1, heuristic="improved", type="alpha-beta")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 19         1          1  None                        naive_agent
# 21         1          1  None                     advanced_agent
# 20         1          1  None                     improved_agent
# 18         1          1  None              improved_random_agent
# 25         1          1     2             improved_minimax_agent
# 24         1          1     1             improved_minimax_agent
# 29         1          1     2     naive_alpha-beta_minimax_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 27         1          1     2             advanced_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 30         1          1     1  improved_alpha-beta_minimax_agent
# 28         1          1     1     naive_alpha-beta_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 22         1          1     1                naive_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 23         1          1     2                naive_minimax_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 26         1          1     1             advanced_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 19     stockfish         False       checkmate: Black wins!           16
# 21     stockfish         False       checkmate: Black wins!           20
# 20     stockfish         False       checkmate: Black wins!           22
# 18     stockfish         False       checkmate: Black wins!           22
# 25     stockfish         False       checkmate: Black wins!           24
# 24     stockfish         False       checkmate: Black wins!           24
# 29     stockfish         False       checkmate: Black wins!           24
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 27     stockfish         False       checkmate: Black wins!           28
# 6   random_agent          True       checkmate: White wins!           29
# 30     stockfish         False       checkmate: Black wins!           30
# 28     stockfish         False       checkmate: Black wins!           32
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 22     stockfish         False       checkmate: Black wins!           46
# 16  random_agent          True       checkmate: White wins!           47
# 23     stockfish         False       checkmate: Black wins!           48
# 12  random_agent         False                  draw: claim           51
# 3   random_agent          True       checkmate: White wins!           51
# 13  random_agent         False              draw: stalemate           53
# 26     stockfish         False       checkmate: Black wins!           60
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 19              12                 13                   25
# 21              12                 13                   25
# 20              11                 12                   23
# 18              12                 13                   25
# 25              14                 16                   30
# 24              13                 15                   28
# 29              10                 14                   24
# 9               15                 11                   26
# 14              16                  5                   21
# 27              11                 14                   25
# 6               16                 12                   28
# 30               9                 13                   22
# 28              15                 15                   30
# 17               9                 15                   24
# 15              15                  2                   17
# 22              13                 14                   27
# 16              13                  7                   20
# 23              12                 14                   26
# 12              15                  2                   17
# 3               10                  6                   16
# 13              14                  1                   15
# 26               8                 11                   19
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Improved Mini-Max with Alpha-Beta-Pruning Agent (Depth 2) vs Stockfish

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=2, heuristic="improved", type="alpha-beta")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 31         1          1     2  improved_alpha-beta_minimax_agent
# 19         1          1  None                        naive_agent
# 21         1          1  None                     advanced_agent
# 20         1          1  None                     improved_agent
# 18         1          1  None              improved_random_agent
# 29         1          1     2     naive_alpha-beta_minimax_agent
# 25         1          1     2             improved_minimax_agent
# 24         1          1     1             improved_minimax_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 27         1          1     2             advanced_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 30         1          1     1  improved_alpha-beta_minimax_agent
# 28         1          1     1     naive_alpha-beta_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 22         1          1     1                naive_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 23         1          1     2                naive_minimax_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 26         1          1     1             advanced_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 31     stockfish         False       checkmate: Black wins!           16
# 19     stockfish         False       checkmate: Black wins!           16
# 21     stockfish         False       checkmate: Black wins!           20
# 20     stockfish         False       checkmate: Black wins!           22
# 18     stockfish         False       checkmate: Black wins!           22
# 29     stockfish         False       checkmate: Black wins!           24
# 25     stockfish         False       checkmate: Black wins!           24
# 24     stockfish         False       checkmate: Black wins!           24
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 27     stockfish         False       checkmate: Black wins!           28
# 6   random_agent          True       checkmate: White wins!           29
# 30     stockfish         False       checkmate: Black wins!           30
# 28     stockfish         False       checkmate: Black wins!           32
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 22     stockfish         False       checkmate: Black wins!           46
# 16  random_agent          True       checkmate: White wins!           47
# 23     stockfish         False       checkmate: Black wins!           48
# 12  random_agent         False                  draw: claim           51
# 3   random_agent          True       checkmate: White wins!           51
# 13  random_agent         False              draw: stalemate           53
# 26     stockfish         False       checkmate: Black wins!           60
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 31              13                 14                   27
# 19              12                 13                   25
# 21              12                 13                   25
# 20              11                 12                   23
# 18              12                 13                   25
# 29              10                 14                   24
# 25              14                 16                   30
# 24              13                 15                   28
# 9               15                 11                   26
# 14              16                  5                   21
# 27              11                 14                   25
# 6               16                 12                   28
# 30               9                 13                   22
# 28              15                 15                   30
# 17               9                 15                   24
# 15              15                  2                   17
# 22              13                 14                   27
# 16              13                  7                   20
# 23              12                 14                   26
# 12              15                  2                   17
# 3               10                  6                   16
# 13              14                  1                   15
# 26               8                 11                   19
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Improved Mini-Max with Alpha-Beta-Pruning Agent (Depth 3) vs Stockfish

# %%
# game = ai.Game()
# white = ai.MiniMaxAgent(max_depth=3, heuristic="improved", type="alpha-beta")
# black = STOCKFISH_PATH
# 
# results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
# df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
# scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
# scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)

# %% [markdown]
# ## Advanced Mini-Max with Alpha-Beta-Pruning Agent (Depth 1) vs Stockfish

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=1, heuristic="advanced", type="alpha-beta")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 31         1          1     2  improved_alpha-beta_minimax_agent
# 19         1          1  None                        naive_agent
# 21         1          1  None                     advanced_agent
# 20         1          1  None                     improved_agent
# 18         1          1  None              improved_random_agent
# 29         1          1     2     naive_alpha-beta_minimax_agent
# 25         1          1     2             improved_minimax_agent
# 24         1          1     1             improved_minimax_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 27         1          1     2             advanced_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 30         1          1     1  improved_alpha-beta_minimax_agent
# 28         1          1     1     naive_alpha-beta_minimax_agent
# 17         1          1  None                       random_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 32         1          1     1  advanced_alpha-beta_minimax_agent
# 22         1          1     1                naive_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 23         1          1     2                naive_minimax_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 26         1          1     1             advanced_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 31     stockfish         False       checkmate: Black wins!           16
# 19     stockfish         False       checkmate: Black wins!           16
# 21     stockfish         False       checkmate: Black wins!           20
# 20     stockfish         False       checkmate: Black wins!           22
# 18     stockfish         False       checkmate: Black wins!           22
# 29     stockfish         False       checkmate: Black wins!           24
# 25     stockfish         False       checkmate: Black wins!           24
# 24     stockfish         False       checkmate: Black wins!           24
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 27     stockfish         False       checkmate: Black wins!           28
# 6   random_agent          True       checkmate: White wins!           29
# 30     stockfish         False       checkmate: Black wins!           30
# 28     stockfish         False       checkmate: Black wins!           32
# 17     stockfish         False       checkmate: Black wins!           36
# 15  random_agent         False              draw: stalemate           39
# 32     stockfish         False       checkmate: Black wins!           46
# 22     stockfish         False       checkmate: Black wins!           46
# 16  random_agent          True       checkmate: White wins!           47
# 23     stockfish         False       checkmate: Black wins!           48
# 12  random_agent         False                  draw: claim           51
# 3   random_agent          True       checkmate: White wins!           51
# 13  random_agent         False              draw: stalemate           53
# 26     stockfish         False       checkmate: Black wins!           60
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 31              13                 14                   27
# 19              12                 13                   25
# 21              12                 13                   25
# 20              11                 12                   23
# 18              12                 13                   25
# 29              10                 14                   24
# 25              14                 16                   30
# 24              13                 15                   28
# 9               15                 11                   26
# 14              16                  5                   21
# 27              11                 14                   25
# 6               16                 12                   28
# 30               9                 13                   22
# 28              15                 15                   30
# 17               9                 15                   24
# 15              15                  2                   17
# 32               6                 12                   18
# 22              13                 14                   27
# 16              13                  7                   20
# 23              12                 14                   26
# 12              15                  2                   17
# 3               10                  6                   16
# 13              14                  1                   15
# 26               8                 11                   19
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Advanced Mini-Max with Alpha-Beta-Pruning Agent (Depth 2) vs Stockfish

# %%
game = ai.Game()
white = ai.MiniMaxAgent(max_depth=2, heuristic="advanced", type="alpha-beta")
black = STOCKFISH_PATH

results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
# Out:
#    round_num iterations depth                        white agent  \
# 31         1          1     2  improved_alpha-beta_minimax_agent
# 19         1          1  None                        naive_agent
# 21         1          1  None                     advanced_agent
# 18         1          1  None              improved_random_agent
# 20         1          1  None                     improved_agent
# 29         1          1     2     naive_alpha-beta_minimax_agent
# 24         1          1     1             improved_minimax_agent
# 25         1          1     2             improved_minimax_agent
# 9          1          1     1             advanced_minimax_agent
# 14         1          1     2  improved_alpha-beta_minimax_agent
# 27         1          1     2             advanced_minimax_agent
# 6          1          1     2                naive_minimax_agent
# 30         1          1     1  improved_alpha-beta_minimax_agent
# 28         1          1     1     naive_alpha-beta_minimax_agent
# 17         1          1  None                       random_agent
# 33         1          1     2  advanced_alpha-beta_minimax_agent
# 15         1          1     1  advanced_alpha-beta_minimax_agent
# 22         1          1     1                naive_minimax_agent
# 32         1          1     1  advanced_alpha-beta_minimax_agent
# 16         1          1     2  advanced_alpha-beta_minimax_agent
# 23         1          1     2                naive_minimax_agent
# 12         1          1     2     naive_alpha-beta_minimax_agent
# 3          1          1  None                     improved_agent
# 13         1          1     1  improved_alpha-beta_minimax_agent
# 26         1          1     1             advanced_minimax_agent
# 10         1          1     2             advanced_minimax_agent
# 8          1          1     2             improved_minimax_agent
# 7          1          1     1             improved_minimax_agent
# 2          1          1  None                        naive_agent
# 11         1          1     1     naive_alpha-beta_minimax_agent
# 5          1          1     1                naive_minimax_agent
# 1          1          1  None              improved_random_agent
# 0          1          1  None                       random_agent
# 4          1          1  None                     advanced_agent
#
#      black agent white_victory                       winner moves_played  \
# 31     stockfish         False       checkmate: Black wins!           16
# 19     stockfish         False       checkmate: Black wins!           16
# 21     stockfish         False       checkmate: Black wins!           20
# 18     stockfish         False       checkmate: Black wins!           22
# 20     stockfish         False       checkmate: Black wins!           22
# 29     stockfish         False       checkmate: Black wins!           24
# 24     stockfish         False       checkmate: Black wins!           24
# 25     stockfish         False       checkmate: Black wins!           24
# 9   random_agent          True       checkmate: White wins!           25
# 14  random_agent          True       checkmate: White wins!           27
# 27     stockfish         False       checkmate: Black wins!           28
# 6   random_agent          True       checkmate: White wins!           29
# 30     stockfish         False       checkmate: Black wins!           30
# 28     stockfish         False       checkmate: Black wins!           32
# 17     stockfish         False       checkmate: Black wins!           36
# 33     stockfish         False       checkmate: Black wins!           38
# 15  random_agent         False              draw: stalemate           39
# 22     stockfish         False       checkmate: Black wins!           46
# 32     stockfish         False       checkmate: Black wins!           46
# 16  random_agent          True       checkmate: White wins!           47
# 23     stockfish         False       checkmate: Black wins!           48
# 12  random_agent         False                  draw: claim           51
# 3   random_agent          True       checkmate: White wins!           51
# 13  random_agent         False              draw: stalemate           53
# 26     stockfish         False       checkmate: Black wins!           60
# 10  random_agent          True       checkmate: White wins!           61
# 8   random_agent         False              draw: stalemate           75
# 7   random_agent          True       checkmate: White wins!           75
# 2   random_agent         False                  draw: claim           77
# 11  random_agent         False                  draw: claim           85
# 5   random_agent         False                  draw: claim          102
# 1   random_agent         False              draw: stalemate          181
# 0   random_agent         False  draw: insufficient material          283
# 4   random_agent         False                  draw: claim          345
#
#    remain_w_pieces remaining_b_pieces remaining_tot_pieces
# 31              13                 14                   27
# 19              12                 13                   25
# 21              12                 13                   25
# 18              12                 13                   25
# 20              11                 12                   23
# 29              10                 14                   24
# 24              13                 15                   28
# 25              14                 16                   30
# 9               15                 11                   26
# 14              16                  5                   21
# 27              11                 14                   25
# 6               16                 12                   28
# 30               9                 13                   22
# 28              15                 15                   30
# 17               9                 15                   24
# 33               6                 12                   18
# 15              15                  2                   17
# 22              13                 14                   27
# 32               6                 12                   18
# 16              13                  7                   20
# 23              12                 14                   26
# 12              15                  2                   17
# 3               10                  6                   16
# 13              14                  1                   15
# 26               8                 11                   19
# 10              15                  2                   17
# 8               15                  1                   16
# 7               15                  3                   18
# 2               13                  2                   15
# 11              16                  5                   21
# 5               14                  3                   17
# 1               14                  1                   15
# 0                2                  1                    3
# 4                5                  6                   11

# %% [markdown]
# ## Advanced Mini-Max with Alpha-Beta-Pruning Agent (Depth 3) vs Stockfish

# %%
# game = ai.Game()
# white = ai.MiniMaxAgent(max_depth=3, heuristic="advanced", type="alpha-beta")
# black = STOCKFISH_PATH
# 
# results = game.run_engine(white, black, NUM_ITERATIONS, visual=None)

# %%
# df = pd.DataFrame(data=results,columns=COLUMNS)

# %%
#update the scoreboard
# scoreboard = scoreboard.append(df, ignore_index=True)

# %% [markdown]
# ### Overall Scoreboard by moves played ascending

# %%
# scoreboard.sort_values(by=['moves_played'], inplace=False, ascending=True)
